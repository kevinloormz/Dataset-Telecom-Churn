# %%
#Importando librerias a utilizar para el analisis del dataset 
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('churn-bigml.csv')
#head primeros 5 registros del csv
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
#shape filas y columnas del csv
df.shape
# Out:
# (2666, 20)

# %%
#columns nombres de columnas del csv
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
#info marco de datos del csv
df.info()
#Se observa una caracteristica bool, 3 de tipo objeto y 16 numericas
#No existen valores faltantes en las columnas entries=2666
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 20 columns):
# State                     2666 non-null object
# Account length            2666 non-null int64
# Area code                 2666 non-null int64
# International plan        2666 non-null object
# Voice mail plan           2666 non-null object
# Number vmail messages     2666 non-null int64
# Total day minutes         2666 non-null float64
# Total day calls           2666 non-null int64
# Total day charge          2666 non-null float64
# Total eve minutes         2666 non-null float64
# Total eve calls           2666 non-null int64
# Total eve charge          2666 non-null float64
# Total night minutes       2666 non-null float64
# Total night calls         2666 non-null int64
# Total night charge        2666 non-null float64
# Total intl minutes        2666 non-null float64
# Total intl calls          2666 non-null int64
# Total intl charge         2666 non-null float64
# ...

# %%
#astype cambiar el tipo de columna 
df['Churn']=df['Churn'].astype('int64')

# %%
#describe características estadísticas básicas solo de columnas int64 o float 64
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     2666.000000  2666.000000            2666.000000         2666.00000
# mean       100.620405   437.438860               8.021755          179.48162
# std         39.563974    42.521018              13.612277           54.21035
# min          1.000000   408.000000               0.000000            0.00000
# 25%         73.000000   408.000000               0.000000          143.40000
# 50%        100.000000   415.000000               0.000000          179.95000
# 75%        127.000000   510.000000              19.000000          215.90000
# max        243.000000   510.000000              50.000000          350.80000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      2666.000000       2666.000000        2666.000000      2666.000000
# mean        100.310203         30.512404         200.386159       100.023631
# ...

# %%
#Estadistica de características no numéricas
df.describe(include=['object','bool'])
# Out:
#        State International plan Voice mail plan
# count   2666               2666            2666
# unique    51                  2               2
# top       WV                 No              No
# freq      88               2396            1933

# %%
#sort_values ordenar por uno o mas campos ascendente o descendente
df.sort_values(by='Total day charge',ascending=False).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 296     CO             154        415                 No              No
# 780     NY              64        415                Yes              No
# 2087    OH             115        510                Yes              No
# 128     OH              83        415                 No              No
# 485     MO             112        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 296                       0              350.8               75
# 780                       0              346.8               55
# 2087                      0              345.3               81
# 128                       0              337.4              120
# 485                       0              335.5               77
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.sort_values(by=['Churn','Total day charge'],ascending=False).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 296     CO             154        415                 No              No
# 780     NY              64        415                Yes              No
# 2087    OH             115        510                Yes              No
# 128     OH              83        415                 No              No
# 485     MO             112        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 296                       0              350.8               75
# 780                       0              346.8               55
# 2087                      0              345.3               81
# 128                       0              337.4              120
# 485                       0              335.5               77
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
#14% Media de diserción de usuarios de la empresa 
df['Churn'].mean()
# Out:
# 0.145536384096024

# %%
#Tiempo promedio de tipos de consumos de los usuarios que abandonan la empresa
df[df['Churn']==1].mean()
# Out:
# Account length            102.319588
# Area code                 437.543814
# Number vmail messages       5.170103
# Total day minutes         205.181186
# Total day calls           101.195876
# Total day charge           34.881340
# Total eve minutes         209.385309
# Total eve calls            99.948454
# Total eve charge           17.797861
# Total night minutes       205.307216
# Total night calls         100.682990
# Total night charge          9.238892
# Total intl minutes         10.819330
# Total intl calls            4.051546
# Total intl charge           2.921727
# Customer service calls      2.206186
# Churn                       1.000000
# dtype: float64

# %%
#Tiempo promedio de usuarios en el telefono durante el dia 
df[df['Churn']==1]['Total day minutes'].mean()
# Out:
# 205.1811855670104

# %%
#Cuál es la duración máxima de las llamadas internacionales entre usuarios leales (Churn == 0) que no tienen un plan internacional
df[(df['Churn'] == 0) & (df['International plan'] == 'No')]['Total intl minutes'].max()
# Out:
# 18.9

# %%
#loc Indexar por nombre
df.loc[0:5, 'State':'Area code']
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415
# 5    AL             118        510

# %%
#iloc Indexar por indece de las columnas 
df.iloc[0:5, 0:3]
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415
